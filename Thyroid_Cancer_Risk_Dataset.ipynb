# %%
import pandas as pd
df=pd.read_csv("thyroid_cancer_risk_data.csv")
print(df)
# Out:
#         Patient_ID  Age  Gender  Country       Ethnicity Family_History  \
# 0                1   66    Male   Russia       Caucasian             No
# 1                2   29    Male  Germany        Hispanic             No
# 2                3   86    Male  Nigeria       Caucasian             No
# 3                4   75  Female    India           Asian             No
# 4                5   35  Female  Germany         African            Yes
# ...            ...  ...     ...      ...             ...            ...
# 212686      212687   58  Female    India           Asian             No
# 212687      212688   89    Male    Japan  Middle Eastern             No
# 212688      212689   72  Female  Nigeria        Hispanic             No
# 212689      212690   85  Female   Brazil  Middle Eastern             No
# 212690      212691   46  Female    Japan  Middle Eastern             No
#
#        Radiation_Exposure Iodine_Deficiency Smoking Obesity Diabetes  \
# 0                     Yes                No      No      No       No
# 1                     Yes                No      No      No       No
# 2                      No                No      No      No       No
# 3                      No                No      No      No       No
# 4                     Yes                No      No      No       No
# ...                   ...               ...     ...     ...      ...
# 212686                 No                No      No     Yes       No
# 212687                 No                No      No     Yes       No
# 212688                 No                No      No      No      Yes
# 212689                 No                No      No      No      Yes
# 212690                 No                No     Yes      No       No
#
#         TSH_Level  T3_Level  T4_Level  Nodule_Size Thyroid_Cancer_Risk  \
# 0            9.37      1.67      6.16         1.08                 Low
# 1            1.83      1.73     10.54         4.05                 Low
# 2            6.26      2.59     10.57         4.61                 Low
# 3            4.10      2.62     11.04         2.46              Medium
# 4            9.10      2.11     10.71         2.11                High
# ...           ...       ...       ...          ...                 ...
# 212686       2.00      0.64     11.92         1.48                 Low
# 212687       9.77      3.25      7.30         4.46              Medium
# 212688       7.72      2.44      8.71         2.36              Medium
# 212689       5.62      2.53      9.62         1.54              Medium
# 212690       5.60      2.73     10.59         2.53                 Low
#
#         Diagnosis
# 0          Benign
# 1          Benign
# 2          Benign
# 3          Benign
# 4          Benign
# ...           ...
# 212686     Benign
# 212687     Benign
# 212688     Benign
# 212689     Benign
# 212690  Malignant
#
# [212691 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212691 entries, 0 to 212690
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Patient_ID           212691 non-null  int64
#  1   Age                  212691 non-null  int64
#  2   Gender               212691 non-null  object
#  3   Country              212691 non-null  object
#  4   Ethnicity            212691 non-null  object
#  5   Family_History       212691 non-null  object
#  6   Radiation_Exposure   212691 non-null  object
#  7   Iodine_Deficiency    212691 non-null  object
#  8   Smoking              212691 non-null  object
#  9   Obesity              212691 non-null  object
#  10  Diabetes             212691 non-null  object
#  11  TSH_Level            212691 non-null  float64
#  12  T3_Level             212691 non-null  float64
#  13  T4_Level             212691 non-null  float64
#  14  Nodule_Size          212691 non-null  float64
#  15  Thyroid_Cancer_Risk  212691 non-null  object
#  16  Diagnosis            212691 non-null  object
# dtypes: float64(4), int64(2), object(11)
# memory usage: 27.6+ MB

# %%
df[df['Gender']=='Female'].shape[0]
# Out:
# 127527

# %%
df.isna().sum()    #Returns a new DataFrame of the same shape as df, where each cell is:
# Out:
# Patient_ID             0
# Age                    0
# Gender                 0
# Country                0
# Ethnicity              0
# Family_History         0
# Radiation_Exposure     0
# Iodine_Deficiency      0
# Smoking                0
# Obesity                0
# Diabetes               0
# TSH_Level              0
# T3_Level               0
# T4_Level               0
# Nodule_Size            0
# Thyroid_Cancer_Risk    0
# Diagnosis              0
# dtype: int64

# %%
df.describe()   #only numeric columns display
# Out:
#          Patient_ID            Age      TSH_Level       T3_Level  \
# count  212691.00000  212691.000000  212691.000000  212691.000000
# mean   106346.00000      51.918497       5.045102       2.001727
# std     61398.74739      21.632815       2.860264       0.866248
# min         1.00000      15.000000       0.100000       0.500000
# 25%     53173.50000      33.000000       2.570000       1.250000
# 50%    106346.00000      52.000000       5.040000       2.000000
# 75%    159518.50000      71.000000       7.520000       2.750000
# max    212691.00000      89.000000      10.000000       3.500000
#
#             T4_Level    Nodule_Size
# count  212691.000000  212691.000000
# mean        8.246204       2.503403
# std         2.164188       1.444631
# min         4.500000       0.000000
# 25%         6.370000       1.250000
# 50%         8.240000       2.510000
# 75%        10.120000       3.760000
# max        12.000000       5.000000

# %%
df.Nodule_Size
# Out:
# 0         1.08
# 1         4.05
# 2         4.61
# 3         2.46
# 4         2.11
#           ...
# 212686    1.48
# 212687    4.46
# 212688    2.36
# 212689    1.54
# 212690    2.53
# Name: Nodule_Size, Length: 212691, dtype: float64

# %%
df[df["Nodule_Size"] >= 4.46]
# Out:
#         Patient_ID  Age  Gender  Country       Ethnicity Family_History  \
# 2                3   86    Male  Nigeria       Caucasian             No
# 17              18   35    Male    Japan        Hispanic             No
# 23              24   56    Male  Nigeria       Caucasian             No
# 25              26   29    Male   Russia           Asian            Yes
# 48              49   58  Female   Russia         African             No
# ...            ...  ...     ...      ...             ...            ...
# 212641      212642   50  Female  Germany       Caucasian            Yes
# 212643      212644   83    Male    China        Hispanic             No
# 212644      212645   66  Female    India         African             No
# 212676      212677   56    Male    Japan        Hispanic             No
# 212687      212688   89    Male    Japan  Middle Eastern             No
#
#        Radiation_Exposure Iodine_Deficiency Smoking Obesity Diabetes  \
# 2                      No                No      No      No       No
# 17                     No                No      No      No       No
# 23                     No                No      No      No      Yes
# 25                     No                No     Yes      No       No
# 48                     No                No      No      No       No
# ...                   ...               ...     ...     ...      ...
# 212641                Yes                No     Yes      No      Yes
# 212643                 No                No      No      No       No
# 212644                 No                No      No     Yes      Yes
# 212676                Yes                No      No      No       No
# 212687                 No                No      No     Yes       No
#
#         TSH_Level  T3_Level  T4_Level  Nodule_Size Thyroid_Cancer_Risk  \
# 2            6.26      2.59     10.57         4.61                 Low
# 17           3.59      1.83      4.95         4.93              Medium
# 23           0.14      0.90      7.93         4.79                 Low
# 25           7.90      0.82      6.63         4.64                High
# 48           4.91      1.24      4.84         4.93              Medium
# ...           ...       ...       ...          ...                 ...
# 212641       0.19      1.05     11.58         4.97                 Low
# 212643       6.05      2.93      6.46         4.57                 Low
# 212644       8.75      0.64      6.70         4.55                 Low
# 212676       6.36      2.24     11.82         4.86              Medium
# 212687       9.77      3.25      7.30         4.46              Medium
#
#         Diagnosis
# 2          Benign
# 17         Benign
# 23         Benign
# 25      Malignant
# 48         Benign
# ...           ...
# 212641     Benign
# 212643     Benign
# 212644     Benign
# 212676     Benign
# 212687     Benign
#
# [23313 rows x 17 columns]

# %%
df.Country
# Out:
# 0          Russia
# 1         Germany
# 2         Nigeria
# 3           India
# 4         Germany
#            ...
# 212686      India
# 212687      Japan
# 212688    Nigeria
# 212689     Brazil
# 212690      Japan
# Name: Country, Length: 212691, dtype: object

# %%
df[df["Country"]=="Germany"].shape[0]
# Out:
# 10557

# %%
df["TSH_Level"].mean()
# Out:
# 5.045102002435476

# %%
df['Thyroid_Cancer_Risk'].value_counts()
# Out:
# Low       108388
# Medium     72400
# High       31903
# Name: Thyroid_Cancer_Risk, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(risk_counts.index, risk_counts.values, color='skyblue')
plt.xlabel('Thyroid Cancer Risk Level')
plt.ylabel('Number of Patients')
plt.title('Distribution of Thyroid Cancer Risk')
plt.show()

# %%
#plt.scatter(df['Age'], df['Nodule_Size'],  color='blue') #T3_Level=Triiodothyronine 
plt.scatter(df['Age'], df['Nodule_Size'], alpha=0.5, color='blue') #Sets the transparency of the dots (0 = fully transparent, 1 = opaque).
plt.xlabel('Age')
plt.ylabel('Nodule_Size')
plt.title('Age vs. Nodule_Size')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar(top_20['Patient_ID'].astype(str), top_20['Risk_Score'], color='red') #astype(str)=patient id convert string
plt.xlabel('Patient ID')
plt.ylabel('Cancer Risk Level (1=Low, 2=Medium, 3=High)')
plt.title('Top 20 Patients by Thyroid Cancer Risk Level')
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x='Thyroid_Cancer_Risk', y='TSH_Level', data=df )
plt.title('TSH Level Distribution by Thyroid Cancer Risk')
plt.xlabel('Cancer Risk Level')
plt.ylabel('TSH Level')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(df['Patient_ID'].head(100), df['T3_Level'].head(100), color='green', marker='o')
plt.title('T3 Level Across First 100 Patients')
plt.xlabel('Patient ID')
plt.ylabel('T3 Level')
plt.grid(True)                       
plt.show()

# %%
sns.scatterplot(x='TSH_Level', y='Nodule_Size', hue='Thyroid_Cancer_Risk', data=df, alpha=0.6)
plt.title('Nodule Size vs. TSH Level by Cancer Risk')
plt.xlabel('TSH Level')
plt.ylabel('Nodule Size')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data = { 'Age': [66, 29, 86, 75, 35, 58, 89, 72, 85, 46],
         'TSH_Level': [9.37, 1.83, 6.26, 4.10, 9.10, 2.00, 9.77, 7.72, 5.62, 5.60],
         'T3_Level': [1.67, 1.73, 2.59, 2.62, 2.11, 0.64, 3.25, 2.44, 2.53, 2.73],
         'Nodule_Size': [1.08, 4.05, 4.61, 2.46, 2.11, 1.48, 4.46, 2.36, 1.54, 2.53]
}
df = pd.DataFrame(data)
fig, axs = plt.subplots(2,2, figsize=(10, 10))  #Creates a 2x2 grid of subplots — a total of 4 individual plots (axes) arranged in 2 rows and 2 columns.
                                                #10,10=10 inches wide and 10 inches tall
axs[0, 0].hist(df['Age'], bins=10, color='skyblue', edgecolor='black')
axs[0, 0].set_title('Age Distribution')
axs[0, 0].set_xlabel('Age')
axs[0, 0].set_ylabel('Frequency')

axs[0, 1].hist(df['TSH_Level'], bins=10, color='lightgreen', edgecolor='black')
axs[0, 1].set_title('TSH Level Distribution')
axs[0, 1].set_xlabel('TSH Level')
axs[0, 1].set_ylabel('Frequency')

axs[1, 0].hist(df['T3_Level'], bins=10, color='salmon', edgecolor='black')
axs[1, 0].set_title('T3 Level Distribution')
axs[1, 0].set_xlabel('T3 Level')
axs[1, 0].set_ylabel('Frequency')

axs[1, 1].hist(df['Nodule_Size'], bins=10, color='plum', edgecolor='black')
axs[1, 1].set_title('Nodule Size Distribution')
axs[1, 1].set_xlabel('Nodule Size')
axs[1, 1].set_ylabel('Frequency')


plt.tight_layout()
plt.show()
